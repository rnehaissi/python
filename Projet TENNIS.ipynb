# %% [markdown]
# <a href="https://colab.research.google.com/github/rnehaissi/python/blob/main/Projet%20TENNIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/rnehaissi/python/main/atp_tennis.csv'
data = pd.read_csv(url)
print(data)
# Out:
#                    Tournament        Date        Series    Court Surface  \
# 0      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 1      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 2      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 3      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 4      Brisbane International  2013-01-01        ATP250  Outdoor    Hard
# ...                       ...         ...           ...      ...     ...
# 25357              Miami Open  2023-03-30  Masters 1000  Outdoor    Hard
# 25358              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25359              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25360              Miami Open  2023-04-01  Masters 1000  Outdoor    Hard
# 25361              Miami Open  2023-04-02  Masters 1000  Outdoor    Hard
#
#                Round  Best of      Player_1      Player_2        Winner  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25362 entries, 0 to 25361
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tournament  25362 non-null  object
#  1   Date        25362 non-null  object
#  2   Series      25362 non-null  object
#  3   Court       25362 non-null  object
#  4   Surface     25362 non-null  object
#  5   Round       25362 non-null  object
#  6   Best of     25362 non-null  int64
#  7   Player_1    25362 non-null  object
#  8   Player_2    25362 non-null  object
#  9   Winner      25362 non-null  object
#  10  Rank_1      25362 non-null  int64
#  11  Rank_2      25362 non-null  int64
#  12  Pts_1       25362 non-null  int64
#  13  Pts_2       25362 non-null  int64
#  14  Odd_1       25362 non-null  float64
#  15  Odd_2       25362 non-null  float64
#  16  score       25362 non-null  object
# dtypes: float64(2), int64(5), object(10)
# memory usage: 3.3+ MB

# %%
data.describe()
# Out:
#             Best of        Rank_1        Rank_2         Pts_1         Pts_2  \
# count  25362.000000  25362.000000  25362.000000  25362.000000  25362.000000
# mean       3.396617     72.601136     71.944720   1575.219107   1564.255264
# std        0.803011     93.999548     89.268571   1931.790990   1905.969182
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000     24.000000     24.000000    640.000000    636.000000
# 50%        3.000000     52.000000     52.000000    937.000000    930.000000
# 75%        3.000000     89.000000     90.000000   1641.000000   1618.750000
# max        5.000000   2146.000000   2159.000000  16950.000000  16950.000000
#
#               Odd_1         Odd_2
# count  25362.000000  25362.000000
# mean       2.685540      2.710894
# std        2.817076      2.888063
# min        0.967000      0.967000
# 25%        1.400000      1.400000
# 50%        1.830000      1.830000
# 75%        2.750000      2.750000
# ...
